# %%
# This code is contributed by Mayank Khanna 
# Python program for implementation of MergeSort
#
#
# ----- Algorithm -----------------------
# ----- MergeSort(arr[], l,  r)
# If r > l
#     1. Find the middle point to divide the array into two halves:  
#             middle m = l+ (r-l)/2
#     2. Call mergeSort for first half:   
#             Call mergeSort(arr, l, m)
#     3. Call mergeSort for second half:
#             Call mergeSort(arr, m+1, r)
#     4. Merge the two halves sorted in step 2 and 3:
#             Call merge(arr, l, m, r)
# ----- Algorithm -----------------------
import random

def mergeSort(arr):
    if len(arr) > 1:
        print("up : " , end=" ")
        printList(arr)
         # Finding the mid of the array
        mid = len(arr)//2
        # Dividing the array elements
        L = arr[:mid]
        # into 2 halves
        R = arr[mid:]
        # Sorting the first half
        mergeSort(L)
        # Sorting the second half
        mergeSort(R)
        i = j = k = 0
        print("mid: " , end=" ")
        printList(arr)
        # Copy data to temp arrays L[] and R[]
        while i < len(L) and j < len(R):
            if L[i] < R[j]:
                arr[k] = L[i]
                i += 1
            else:
                arr[k] = R[j]
                j += 1
            k += 1
        # Checking if any element was left
        while i < len(L):
            arr[k] = L[i]
            i += 1
            k += 1
  
        while j < len(R):
            arr[k] = R[j]
            j += 1
            k += 1
        print("low: " , end=" ")
        printList(arr)
# Code to print the list  
def printList(arr):
    for i in range(len(arr)):
        print(arr[i], end=" ")
    print()

# %%
# Driver Code
if __name__ == '__main__':
    arr = [12, 11, 13, 5, 6, 7] 
    # random.randint(0, 9)
    N = 20
    arr  = [random.randint(0, 100) for i in range(N)]
    print("Given array is", end="\n")
    printList(arr)
    mergeSort(arr)
    print("Sorted array is: ", end="\n")
    printList(arr)
# Out:
# Given array is
# 73 63 31 55 46 7 60 21 40 81 0 28 92 60 53 60 65 77 61 38
# up :  73 63 31 55 46 7 60 21 40 81 0 28 92 60 53 60 65 77 61 38
# up :  73 63 31 55 46 7 60 21 40 81
# up :  73 63 31 55 46
# up :  73 63
# mid:  73 63
# low:  63 73
# up :  31 55 46
# up :  55 46
# mid:  55 46
# low:  46 55
# mid:  31 55 46
# low:  31 46 55
# mid:  73 63 31 55 46
# low:  31 46 55 63 73
# up :  7 60 21 40 81
# up :  7 60
# mid:  7 60
# low:  7 60
# up :  21 40 81
# up :  40 81
# mid:  40 81
# low:  40 81
# mid:  21 40 81
# low:  21 40 81
# mid:  7 60 21 40 81
# low:  7 21 40 60 81
# mid:  73 63 31 55 46 7 60 21 40 81
# low:  7 21 31 40 46 55 60 63 73 81
# up :  0 28 92 60 53 60 65 77 61 38
# up :  0 28 92 60 53
# up :  0 28
# mid:  0 28
# low:  0 28
# up :  92 60 53
# up :  60 53
# mid:  60 53
# low:  53 60
# mid:  92 60 53
# low:  53 60 92
# mid:  0 28 92 60 53
# low:  0 28 53 60 92
# up :  60 65 77 61 38
# up :  60 65
# mid:  60 65
# low:  60 65
# up :  77 61 38
# up :  61 38
# mid:  61 38
# low:  38 61
# mid:  77 61 38
# low:  38 61 77
# mid:  60 65 77 61 38
# low:  38 60 61 65 77
# mid:  0 28 92 60 53 60 65 77 61 38
# low:  0 28 38 53 60 60 61 65 77 92
# mid:  73 63 31 55 46 7 60 21 40 81 0 28 92 60 53 60 65 77 61 38
# low:  0 7 21 28 31 38 40 46 53 55 60 60 60 61 63 65 73 77 81 92
# Sorted array is:
# 0 7 21 28 31 38 40 46 53 55 60 60 60 61 63 65 73 77 81 92
